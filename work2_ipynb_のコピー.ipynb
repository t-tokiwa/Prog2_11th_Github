# %% [markdown]
# <a href="https://colab.research.google.com/github/Moriyuki29/Prog2_11th/blob/main/work2_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
n1,n2,count,list1,list2=0,0,0,[],[]
num1=int(input("横何マスの計算がしたいですか？"))
num2=int(input("縦何マスの計算がしたいですか？"))
num3=int(input("生成される数値の下限を設定してください"))
num4=int(input("生成される数値の上限を設定してください"))
array1=np.random.randint(num3,num4+1,(1,num1))
while n1<num1:
  list1.append(array1[0,n1])
  n1+=1
array2=np.random.randint(num3,num4+1,(num2,1))
while n2<num2:
  list2.append(array2[n2,0])
  n2+=1
df=pd.DataFrame(np.zeros((num2,num1)))
df.index=[list2]
df.columns=[list1]
df=df.astype("int")
display(df)
array_ans=np.zeros((num2,num1))
print("計算に入ります")
for i in range(num2):
  for j in range(num1):
    print("現在"+str(i+1)+"行"+str(j+1)+"列目")
    ans=int(input("A:"))
    array_ans[i,j]=ans
    count+=1
    if count%6==0:
      print("再度表を表示します")
      display(df)
df_ans=pd.DataFrame(array_ans)
df_ans=df_ans.astype("int")
df_true=pd.DataFrame(array1*array2)
css={"background-color": "red"}
df_ans.index=[list2]
df_ans.columns=[list1]
if np.all(array_ans==array1*array2):
  print("Congratulation!!")
else:
  print("Fail...")
print("これがあなたの回答です")
display(df_ans)
df_true.index=[list2]
df_true.columns=[list1]
print("これが模範解答です")
display(df_true)
# Out:
# 横何マスの計算がしたいですか？2
# 縦何マスの計算がしたいですか？2
# 生成される数値の下限を設定してください3
# 生成される数値の上限を設定してください4
#    3  4
# 4  0  0
# 3  0  0
# 計算に入ります
# 現在1行1列目
# A:12
# 現在1行2列目
# A:2
# 現在2行1列目
# A:2
# 現在2行2列目
# A:16
# 12.0 12
# 2.0 16
# 2.0 9
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-bfbed5caa055> in <cell line: 34>()
#      36     print(array_ans[k,l],(array1*array2)[k,l])
#      37     if np.any(array_ans[k,l]!=(array1*array2)[k,l]):
# ---> 38       df_ans=df_ans.style.set_properties(subset=pd.IndexSlice[k,l:], **css)
#      39 df_ans.index=[list2]
#      40 df_ans.columns=[list1]
#
# AttributeError: 'Styler' object has no attribute 'style'
