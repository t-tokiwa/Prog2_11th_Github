# %% [markdown]
# <a href="https://colab.research.google.com/github/fujii-hcu/Prog2_11th/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
# 保存パスの指定
save_path = "./"
def main():
    # カメラのキャプチャを開始
    cam = cv2.VideoCapture(0)
    # フレームの初期化 --- (*1)
    img1 = img2 = img3 = get_image(cam)
    th = 100
    num = 1
    react=0
    while True:
        # Enterキーが押されたら終了
        if cv2.waitKey(1) & 0xff == ord("q"): break
        # 差分を調べる --- (*2)
        diff = check_image(img1, img2, img3)
        # 差分がthの値以上なら動きがあったと判定 --- (*3)
        cnt = cv2.countNonZero(diff)
        if cnt > th:
            print("カメラに動きを検出")
            cv2.imshow('PUSH ENTER KEY', img3)
            # 写真を画像 --- (*4)
            #cv2.imwrite(save_path + str(num) + ".jpg", img3)
            #num +=1
            react=0
        else:
            cv2.imshow('PUSH ENTER KEY', diff)
            react+=1
        # 比較用の画像を保存 --- (*5)
        img1, img2, img3 = (img2, img3, get_image(cam))
    # 後始末
    cam.release()
    cv2.destroyAllWindows()

# 画像に動きがあったか調べる関数
def check_image(img1, img2, img3):
    # グレイスケール画像に変換 --- (*6)
    gray1 = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
    gray3 = cv2.cvtColor(img3, cv2.COLOR_RGB2GRAY)
    # 絶対差分を調べる --- (*7)
    diff1 = cv2.absdiff(gray1, gray2)
    diff2 = cv2.absdiff(gray2, gray3)
    # 論理積を調べる --- (*8)
    diff_and = cv2.bitwise_and(diff1, diff2)
    # 白黒二値化 --- (*9)
    _, diff_wb = cv2.threshold(diff_and, 30, 255, cv2.THRESH_BINARY)
    # ノイズの除去 --- (*10)
    diff = cv2.medianBlur(diff_wb, 5)
    return diff

# カメラから画像を取得する
def get_image(cam):
    img = cam.read()[1]
    img = cv2.resize(img, (600, 400))
    return img
main()

import time
import RPi.GPIO as GPIO
GPIO.setmode(GPI0.BCM)
GPIO.setup(26,GPIO.IN,pull_up_down=GPIO.PUD_DOWN)
GPIO.setup(21,GPIO.OUT)
pwm=GPIO.PWM(21,200)

data=[0,0,0,0,0,0,0]
jweek=["月曜日","火曜日","水曜日","木曜日","金曜日","土曜日","日曜日"]
preweek=0
renew=0

while True:
  print("1:月曜, 2:火曜, 3:水曜, 4:木曜, 5:金曜, 6:土曜, 7:日曜")
  while True:
    week=int(input("勉強する曜日の数字を入力してね"))
    if week<=7 & week>=1:break
    else: continue

  if week<=preweek:
    print(f"{jweek[week-1]}にデータを追加しますか？")
    while True:
      answer=int(input("1:はい, 2:いいえ"))
      if answer==1 or answer==2:break
    if answer==2:
      print("先週はお疲れ様でした。先週のデータは以下です")

      renew=0
    else:
      print("かしこまりました、それでは頑張ってください")
      renew=1
    time_study=int(input("１セット、何分勉強しますか？"))
    time_rest=int(input("１セット、何分休憩しますか？"))
    studytime=time_study*60
    print("準備が良ければ、スイッチを押してください")
    #wait_until()
    time_first=time.time()
    notime=0
    while True:
      ### お手洗いなどの中断機能
      if GPIO.input(26)==True:
        notime_first=time.time()
        print("計測を中断します")
        time.sleep(3)
        while True:
        if GPIO.input(26)==True:
          print("計測を再開します、頑張ってください！")
          notime+=time.time()-notime_first
          break
      ### 一定時間カメラの反応がない場合
      if react>=300:
        notime_first=time.time()
        #ブザーを鳴らす
        #wait_until()
        notime+=time.time()-notime_first
      ### 勉強時間が設定した時間に到達した場合
      if time.time() - time_first - notime >= studytime:
        print(f"お疲れ様です！ {time_study}分勉強しました.")
        print(f"{time_rest}分休憩してください")
        time.sleep(time_rest*60)






def wait_until(v): #スイッチの入力検知
  while GPIO.input(26) != v:
    time.sleep(0.01)
